# %%
pip install tensorflow-macos==2.15.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow-macos==2.15.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (4.25.8)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow-macos==2.15.0) (58.0.4)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow-macos==2.15.0) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (4.15.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (1.76.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorflow-macos==2.15.0) (2.15.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (2.47.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (1.2.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.9)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.1.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (2026.2.25)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (0.6.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0) (0.37.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.3.1)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/sheenachanda/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , SimpleRNN ,Bidirectional ,Input
from tensorflow.keras.optimizers import Adam

# %%
import pandas as pd
input_path ="./HistoricalData_1772703629758.csv"
df = pd.read_csv(input_path)  
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
# df = df[['Close']]  
print(df.head(10))
print(df.dtypes)
# Out:
#            Close/Last    Volume      Open     High       Low
# Date
# 2026-03-04    $262.52  39803120   $264.65  $266.15   $261.42
# 2026-03-03    $263.75  38568920   $263.48  $265.56   $260.13
# 2026-03-02    $264.72  41827950   $262.41  $266.53   $260.20
# 2026-02-27    $264.18  72366510   $272.81  $272.81   $262.89
# 2026-02-26    $272.95  32345110  $274.945  $276.11  $270.795
# 2026-02-25    $274.23  33714340   $271.78  $274.94   $271.05
# 2026-02-24    $272.14  47014620   $267.86  $274.89   $267.71
# 2026-02-23    $266.18  37308160   $263.49  $269.43  $263.381
# 2026-02-20    $264.58  42070500   $258.97  $264.75   $258.16
# 2026-02-19    $260.58  30845290   $262.60  $264.48   $260.05
# Close/Last    object
# Volume         int64
# Open          object
# High          object
# Low           object
# dtype: object

# %%
# Clean price columns: remove $, convert to float
price_cols = ['Close/Last', 'Open', 'High', 'Low']

for col in price_cols:
    # Remove $ and convert to float
    df[col] = df[col].str.replace('$', '').str.replace(',', '').astype(float)

# For RNN modeling, use float32 (more efficient, sufficient precision)
price_cols = ['Close/Last', 'Open', 'High', 'Low']
for col in price_cols:
    df[col] = df[col].astype(np.float32)


# Rename the column to 'Close'
df = df.rename(columns={'Close/Last': 'Close'})

print(df.head())
print(df.dtypes)
# Out:
#                  Close    Volume        Open        High         Low
# Date
# 2026-03-04  262.519989  39803120  264.649994  266.149994  261.420013
# 2026-03-03  263.750000  38568920  263.480011  265.559998  260.130005
# 2026-03-02  264.720001  41827950  262.410004  266.529999  260.200012
# 2026-02-27  264.179993  72366510  272.809998  272.809998  262.890015
# 2026-02-26  272.950012  32345110  274.945007  276.109985  270.795013
# Close     float32
# Volume      int64
# Open      float32
# High      float32
# Low       float32
# dtype: object
